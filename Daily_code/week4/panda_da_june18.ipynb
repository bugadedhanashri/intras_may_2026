# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.shape
# Out:
# (5, 5)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    5 non-null      int64
#  1   name    5 non-null      object
#  2   class   5 non-null      object
#  3   marks   5 non-null      float64
#  4   age     5 non-null      int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 332.0+ bytes

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(7)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.tail()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.tail(3)
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20]], dtype=object)

# %%
df.T
# Out:
#            0      1       2        3      4
# roll       1      2       3        4      5
# name    anil   amit  aniket  ajinkya   asha
# class     TE     TE      BE       TE     TE
# marks  56.77  59.77   76.88    69.66  63.28
# age       22     21      19       20     20

# %%
# sciling

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.iloc[1:4, 1:4]
# Out:
#       name class  marks
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66

# %%
df.iloc[1:5 ,[0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28

# %%
df.iloc[[1,2,3,4], [0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28

# %%
df.iloc[4, 1] = 'geet'

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     geet    TE  63.28   20

# %%
# loc

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     geet    TE  63.28   20

# %%
df.loc[2:5, 'name']
# Out:
# 2     aniket
# 3    ajinkya
# 4       geet
# Name: name, dtype: object

# %%
df.loc[2:5,['name', 'class']]
# Out:
#       name class
# 2   aniket    BE
# 3  ajinkya    TE
# 4     geet    TE

# %%
df.loc[:, 'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       geet
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       geet
# Name: name, dtype: object

# %%
df[['name','class']]
# Out:
#       name class
# 0     anil    TE
# 1     amit    TE
# 2   aniket    BE
# 3  ajinkya    TE
# 4     geet    TE

# %%
# methods on columns/series

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     geet    TE  63.28   20

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       GEET
# Name: name, dtype: object

# %%
# add or modify columns

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     geet    TE  63.28   20

# %%
gender = ['m','m','m','m','f']

# %%
df['gender'] = gender

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0     1     anil    TE  56.77   22      m
# 1     2     amit    TE  59.77   21      m
# 2     3   aniket    BE  76.88   19      m
# 3     4  ajinkya    TE  69.66   20      m
# 4     5     geet    TE  63.28   20      f

# %%
df['roll'] = df['roll'] + 100

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0   101     anil    TE  56.77   22      m
# 1   102     amit    TE  59.77   21      m
# 2   103   aniket    BE  76.88   19      m
# 3   104  ajinkya    TE  69.66   20      m
# 4   105     geet    TE  63.28   20      f

# %%
# add new column cgpa
# values should =>marks/10 + 1.5

# %%
df['cgpa'] = df['marks']/10 + 1.5

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
df.sort_values(by= 'name')
# Out:
#    roll     name class  marks  age gender   cgpa
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 0   101     anil    TE  56.77   22      m  7.177
# 4   105     geet    TE  63.28   20      f  7.828

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
# sort by class and then marks simulteneously and check the result

# %%
df.sort_values(by=['class', 'marks'])
# Out:
#    roll     name class  marks  age gender   cgpa
# 2   103   aniket    BE  76.88   19      m  9.188
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 4   105     geet    TE  63.28   20      f  7.828
# 3   104  ajinkya    TE  69.66   20      m  8.466

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
df["marks"].mean()
# Out:
# np.float64(65.272)

# %%
df['marks'].max()
# Out:
# 76.88

# %%
df.describe()
# Out:
#              roll      marks        age      cgpa
# count    5.000000   5.000000   5.000000  5.000000
# mean   103.000000  65.272000  20.400000  8.027200
# std      1.581139   8.070382   1.140175  0.807038
# min    101.000000  56.770000  19.000000  7.177000
# 25%    102.000000  59.770000  20.000000  7.477000
# 50%    103.000000  63.280000  20.000000  7.828000
# 75%    104.000000  69.660000  21.000000  8.466000
# max    105.000000  76.880000  22.000000  9.188000

# %%
#groupby

# %%
gr = df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2], 'TE': [0, 1, 3, 4]}

# %%
gr.get_group('BE')
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   103  aniket    BE  76.88   19      m  9.188

# %%
gr.min()
# Out:
#        roll     name  marks  age gender   cgpa
# class
# BE      103   aniket  76.88   19      m  9.188
# TE      101  ajinkya  56.77   20      f  7.177

# %%
gr['marks'].mean()
# Out:
# class
# BE    76.88
# TE    62.37
# Name: marks, dtype: float64

# %%
# boolean filtering

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
df['marks'] > 60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: marks, dtype: bool

# %%
df[df['marks'] > 60]
# Out:
#    roll     name class  marks  age gender   cgpa
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
# filter the data of those student -> marks > 60 and belong to BE class

# %%
f = df[(df['class']=='BE')&(df['marks']>60)]

# %%
f
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   103  aniket    BE  76.88   19      m  9.188

# %%
# drop ->drop columns

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
df.drop(4)
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466

# %%
df.drop([0,3,2])
# Out:
#    roll  name class  marks  age gender   cgpa
# 1   102  amit    TE  59.77   21      m  7.477
# 4   105  geet    TE  63.28   20      f  7.828

# %%
# drop name column

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
df.drop('name', axis = 1)
# Out:
#    roll class  marks  age gender   cgpa
# 0   101    TE  56.77   22      m  7.177
# 1   102    TE  59.77   21      m  7.477
# 2   103    BE  76.88   19      m  9.188
# 3   104    TE  69.66   20      m  8.466
# 4   105    TE  63.28   20      f  7.828

# %%
# drop name and class

# %%
df.drop(['name','class'], axis = 1)
# Out:
#    roll  marks  age gender   cgpa
# 0   101  56.77   22      m  7.177
# 1   102  59.77   21      m  7.477
# 2   103  76.88   19      m  9.188
# 3   104  69.66   20      m  8.466
# 4   105  63.28   20      f  7.828

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
df.drop(['gender', 'cgpa'], axis = 1, inplace = True)

# %%
df
# create a dataframe
# columns -> roll, gender, cgpa
# roll column will have the same values as that of in the df dataframe
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     geet    TE  63.28   20

# %%
newdf = pd.DataFrame({
    'roll': df['roll'],
    'gender':gender,
    'cgpa':df['marks']/10 + 1.5
})
newdf
# Out:
#    roll gender   cgpa
# 0   101      m  7.177
# 1   102      m  7.477
# 2   103      m  9.188
# 3   104      m  8.466
# 4   105      f  7.828

# %%
pd.merge(df, newdf)
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     geet    TE  63.28   20      f  7.828

# %%
# cocat

# %%
# load student5.csv

# %%
newdf = pd.read_csv('student5.csv')
newdf
# Out:
#   roll\tname\tclass\tmarks\tage
# 0      1\tsurbhi\tTE\t67.44\t23
# 1       2\tsujay\tTE\t74.12\t22
# 2     3\tsubhash\tBE\t82.44\t21
# 3      4\tsachin\tTE\t59.33\t21
# 4     5\tshalini\tTE\t63.45\t20

# %%
pd.concat([df, newdf], ignore_index= True)
# Out:
#     roll     name class  marks   age roll\tname\tclass\tmarks\tage
# 0  101.0     anil    TE  56.77  22.0                           NaN
# 1  102.0     amit    TE  59.77  21.0                           NaN
# 2  103.0   aniket    BE  76.88  19.0                           NaN
# 3  104.0  ajinkya    TE  69.66  20.0                           NaN
# 4  105.0     geet    TE  63.28  20.0                           NaN
# 5    NaN      NaN   NaN    NaN   NaN      1\tsurbhi\tTE\t67.44\t23
# 6    NaN      NaN   NaN    NaN   NaN       2\tsujay\tTE\t74.12\t22
# 7    NaN      NaN   NaN    NaN   NaN     3\tsubhash\tBE\t82.44\t21
# 8    NaN      NaN   NaN    NaN   NaN      4\tsachin\tTE\t59.33\t21
# 9    NaN      NaN   NaN    NaN   NaN     5\tshalini\tTE\t63.45\t20

# %%
f = df[(df['marks'] > 60) & (df['class'] == 'BE')]

# %%
f.to_csv('op.csv', index= False)
