# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([10,23,29,34,39,45,50])
y = np.array([14,21,31,43,55,58,76])
z = np.array([56,50,44,37,26,20,16])

# %%
# line chart

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart:x vs y ")
plt.plot(x, y, marker = 'o',mfc = "red", ls= '--',);
plt.grid();
## o,*,h,<,>

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart:x vs y ")
plt.plot(x, y, marker = 'o',mfc = "red", ls= '--',label = '2024');
plt.plot(x, y, marker = 'o',mfc = "black", ls= '--', color = 'orange',label = '2025');
plt.grid();
plt.legend();

# %%
plt.subplot(2,2,1)
plt.xlabel("x values")
plt.ylabel("yvalues")
plt.title("line chart:x vs y")
plt.plot(x, y, marker ='o', mfc = 'red', ls ='--')
plt.grid();

plt.subplot(2,2,2)
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart: x vs y")
plt.plot(x, z,marker ='o',mfc = "black", ls= '--', color = 'orange',label = '2025');

# %%
# bar chart

# %%
cources =['python', 'lisp' ,'c', 'R', 'php']
students = [68, 30, 47, 39, 60]

# %%
plt.bar(cources, students , color = 'pink', edgecolor = 'red');

# %%
plt.title("student enrollment")
plt.xlabel("cources")
plt.ylabel("no. of students enrolled")

plt.bar(cources, students , color = 'pink', edgecolor = 'red');
plt.grid();
# load student.csv->plot bar graph student name vs marks with proper labels

# %%
df = pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
plt.title("student marks")
plt.xlabel("name")
plt.ylabel("marks")

plt.xticks(rotation = 45)
plt.title('Student Name vs Marks')
plt.bar(df['name'], df['marks'], color='purple');

# %%
## load -> social_network_Ads.csv
#plot bar graph showing the count of how many people purches and how man did not
# purchased column =>  0 -> purchased, 1->not purchased

# %%
ads = pd.read_csv('Social_Network_Ads.csv')
ads
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
ads['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
ads['Purchased'].value_counts().index
# Out:
# Index([0, 1], dtype='int64', name='Purchased')

# %%
plt.bar(ads['Purchased'].value_counts().index, ads['Purchased'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
# scatter chart

# %%
plt.scatter(x, y, color= 'red');

# %%
ads.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
plt.scatter(ads['EstimatedSalary'], ads['Age']);

# %%
plt.figure(figsize=(16,9))
plt.scatter(ads['EstimatedSalary'], ads['Age'],c = ads['Purchased']);

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris);

# %%
sns.pairplot(iris ,hue = 'species', color);

# %%
import matplotlib.pyplot as plt

# %%
# univariate analysis
plt.xticks(range(0, 70, 2), rotation = 45)
plt.yticks(range(0 , 80, 5))
plt.hist(ads['Age'], bins= 15);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 plt.xticks(range(0, 70, 2), rotation = 45)
#       3 plt.yticks(range(0 , 80, 5))
# ----> 4 plt.hist(ads['Age'], bins= 15);
#
# NameError: name 'ads' is not defined

# %%
import pandas as pd
ads = pd.read_csv('Social_Network_Ads.csv')
ads
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
# for age col, on put the following values at the index
# 2 -> 8, 3 ->85

# %%
ads.loc[[2, 3], 'Age'] = [8, 85]

# %%
plt.boxplot(ads['Age']);

# %%
# practices =>
# load the tips dataset from seaborn
#do detailes EDA (charts along with explaination of what we r understanding from them)
# u can use official documentation for ref

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 2. Load dataset
tips = sns.load_dataset("tips")

# 3. Basic info
print(tips.head())
print(tips.shape)
print(tips.info())
print(tips.describe())

# ---------------------------
# 4. Univariate Analysis
# ---------------------------

# Tip distribution
plt.figure()
plt.hist(tips['tip'], bins=15)
plt.title("Tip Distribution")
plt.xlabel("Tip")
plt.ylabel("Frequency")
plt.show()

# Total bill distribution
plt.figure()
plt.hist(tips['total_bill'], bins=15)
plt.title("Total Bill Distribution")
plt.xlabel("Total Bill")
plt.ylabel("Frequency")
plt.show()

# ---------------------------
# 5. Categorical Analysis
# ---------------------------

# Gender count
plt.figure()
sns.countplot(x='sex', data=tips)
plt.title("Gender Count")
plt.show()

# Day wise customers
plt.figure()
sns.countplot(x='day', data=tips)
plt.title("Customers per Day")
plt.show()

# ---------------------------
# 6. Bivariate Analysis
# ---------------------------

# Bill vs Tip
plt.figure()
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Total Bill vs Tip")
plt.show()

# Tip by Gender
plt.figure()
sns.boxplot(x='sex', y='tip', data=tips)
plt.title("Tip by Gender")
plt.show()

# Tip by Day
plt.figure()
sns.boxplot(x='day', y='tip', data=tips)
plt.title("Tip by Day")
plt.show()

# ---------------------------
# 7. Multivariate Analysis
# ---------------------------

# Smoker effect
plt.figure()
sns.scatterplot(x='total_bill', y='tip', hue='smoker', data=tips)
plt.title("Bill vs Tip (Smoker vs Non-Smoker)")
plt.show()

# Pairplot
sns.pairplot(tips, hue='sex')
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# (244, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None
#        total_bill         tip        size
# ...
