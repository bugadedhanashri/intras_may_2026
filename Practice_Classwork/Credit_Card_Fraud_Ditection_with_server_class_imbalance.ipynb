# %%
#Import Data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("creditcard.csv.zip")
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
# Data Cleaning

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
sns.countplot(x='Class', data=df)

plt.xlabel("Class")
plt.ylabel("Number of Transactions")
plt.title("Class Distribution")

plt.show()

# %%
# Fraud Percentage Check

# %%
df['Class'].value_counts(normalize=True)*100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
#Amount Distribution (Histogram)

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Amount'], bins=50)

plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.title("Transaction Amount Distribution")

plt.show()

# %%
# Time Distribution (Histogram)

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Time'], bins=50)

plt.xlabel("Time")
plt.ylabel("Frequency")
plt.title("Transaction Time Distribution")

plt.show()

# %%
# V Features Analysis (V1 - V28)

# %%
# V1 - v4 Feature Analysis

# %%
one = df[['V1','V2','V3','V4','Class']]

sns.pairplot(one, hue='Class')

plt.show()

# %%
# V4 -v8 Feature Analysis

# %%
two = df[['V5','V6','V7','V8','Class']]

sns.pairplot(two, hue='Class')

plt.show()

# %%
# V9- v12 Feature Analysis

# %%
three = df[['V9','V10','V11','V12','Class']]

sns.pairplot(three, hue='Class')

plt.show()

# %%
# v13 - v16 Feature Analysis

# %%
four = df[['V13','V14','V15','V16','Class']]

sns.pairplot(four, hue='Class')

plt.show()

# %%
# V17 - V20 Feature Analysis

# %%
five = df[['V17','V18','V19','V20','Class']]

sns.pairplot(five, hue='Class')

plt.show()

# %%
# v21 - v24 Feature Analysis

# %%
six = df[['V21','V22','V23','V24','Class']]

sns.pairplot(six, hue='Class')

plt.show()

# %%
# v25 - v28 Feature Analysis

# %%
seven = df[['V25','V26','V27','V28','Class']]

sns.pairplot(seven, hue='Class')

plt.show()

# %%
# 4  Outlier Detection and Removal

# %%
plt.figure(figsize=(8,5))

plt.boxplot(df['Amount'])

plt.xlabel("Amount")
plt.ylabel("Value")
plt.title("Amount Outlier Detection")

plt.show()

# %%
# Outlier Detection (V1 - V4)

# %%
id="out1"
features = ['V1','V2','V3','V4']

plt.figure(figsize=(10,6))

df[features].boxplot()

plt.title("Outlier Detection (V1 - V4)")
plt.ylabel("Value")

plt.show()

# %%
# Outlier Detection (V5 - V8)

# %%
features = ['V5','V6','V7','V8']

plt.figure(figsize=(10,6))

df[features].boxplot()

plt.title("Outlier Detection (V5 - V8)")
plt.ylabel("Value")

plt.show()

# %%
# Outlier Detection (V9 - V12)

# %%
features = ['V9','V10','V11','V12']

plt.figure(figsize=(10,6))

df[features].boxplot()

plt.title("Outlier Detection (V9 - V12)")
plt.ylabel("Value")

plt.show()

# %%
# Outlier Detection (V13 - V16)

# %%
features = ['V13','V14','V15','V16']

plt.figure(figsize=(10,6))

df[features].boxplot()

plt.title("Outlier Detection (V13 - V16)")
plt.ylabel("Value")

plt.show()

# %%
#  Outlier Detection (V17 - V20)

# %%
features = ['V17','V18','V19','V20']

plt.figure(figsize=(10,6))

df[features].boxplot()

plt.title("Outlier Detection (V17 - V20)")
plt.ylabel("Value")

plt.show()

# %%
# Outlier Detection (V21 - V24)

# %%
features = ['V21','V22','V23','V24']

plt.figure(figsize=(10,6))

df[features].boxplot()

plt.title("Outlier Detection (V21 - V24)")
plt.ylabel("Value")

plt.show()

# %%
# Outlier Detection (V25 - V28)

# %%
features = ['V25','V26','V27','V28']

plt.figure(figsize=(10,6))

df[features].boxplot()

plt.title("Outlier Detection (V25 - V28)")
plt.ylabel("Value")

plt.show()

# %%
# 5 Data Balancing / Resampling

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
sns.countplot(x='Class', data=df)

plt.xlabel("Class")
plt.ylabel("Number of Transactions")
plt.title("Class Distribution Before Balancing")

plt.show()
