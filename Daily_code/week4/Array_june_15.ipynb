# %%
#NumPy

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
## np means numerical python ie. nick name

# %%
# Creating Arrays

# %%
sample_array = np.array([1,2,3,4])

# %%
sample_array
# Out:
# array([1, 2, 3, 4])

# %%
sample_array1 = np.array([1,2,3,4,5,6])

# %%
sample_array1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# 2D Array(a Matrix) with two rows and 2 columns

# %%
sample_array_2 = np.array([[1,2],[3,4]])

# %%
sample_array_2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
sample_array_3 = np.array([[11,22],[33,44]])

# %%
sample_array_3
# Out:
# array([[11, 22],
#        [33, 44]])

# %%
# 3D Tensor(2 matrices, each with 2 rows and 2 columns )

# %%
sample_tensor_3 = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])

# %%
sample_tensor_3
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
sample_tensor_5 = np.array([[[1,33],[3,4]],[[5,6],[7,8]]])

# %%
sample_tensor_5
# Out:
# array([[[ 1, 33],
#         [ 3,  4]],
#
#        [[ 5,  6],
#         [ 7,  8]]])

# %%
### Dimentions

# %%
## jr array 0 dimention cha asel tr tyala scal mhanayache
## 0-D Array(Scaller)5
##1-D Array(vector)[1,2,3,4]
## jr two dimentional array tr tyala Matrix mhanayache 
##2-D Arrya (Matrix)(rows and columns)
##3-D Array(Tensor) (Page,row,columns )

# %%
## Array properties

# %%
sample_array = np.array([[1,2,3],[5,6,7]])

# %%
sample_array
# Out:
# array([[1, 2, 3],
#        [5, 6, 7]])

# %%
#Shape

# %%
sample_array.shape
# Out:
# (2, 3)

# %%
#dimentions

# %%
sample_array.ndim
# Out:
# 2

# %%
## total elements

# %%
sample_array.size
# Out:
# 6

# %%
# Data type

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
sample_array = np.array([[[1,2,3],[43,56,78]],[[1,4,5,],[5,7,8]],[[3,7,9],[1,3,4]]])

# %%
sample_array
# Out:
# array([[[ 1,  2,  3],
#         [43, 56, 78]],
#
#        [[ 1,  4,  5],
#         [ 5,  7,  8]],
#
#        [[ 3,  7,  9],
#         [ 1,  3,  4]]])

# %%
sample_array.shape
# Out:
# (3, 2, 3)

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
sample_array.ndim
# Out:
# 3

# %%
sample_array.size
# Out:
# 18

# %%
# Special Array

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.arange(0,50,5)
# Out:
# array([ 0,  5, 10, 15, 20, 25, 30, 35, 40, 45])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.linspace(0,1,10)
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])

# %%
#Indexing & Slicing

# %%
sample_array = np.array([10,20,30,40])

# %%
sample_array
# Out:
# array([10, 20, 30, 40])

# %%
sample_array[0]
# Out:
# np.int64(10)

# %%
sample_array[2]
# Out:
# np.int64(30)

# %%
sample_array[-1]
# Out:
# np.int64(40)

# %%
# Slicing

# %%
sample_array[1:3]
# Out:
# array([20, 30])

# %%
# Array Operation

# %%
a = np.array([1,2,3])

# %%
b = np.array([4,5,6])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b
# Out:
# array([4, 5, 6])

# %%
a + b
# Out:
# array([5, 7, 9])

# %%
a - b
# Out:
# array([-3, -3, -3])

# %%
a * b
# Out:
# array([ 4, 10, 18])

# %%
a / b
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
a = np.array([22,11,33])

# %%
b = np.array([11,22,33])

# %%
a
# Out:
# array([22, 11, 33])

# %%
b
# Out:
# array([11, 22, 33])

# %%
a + b
# Out:
# array([33, 33, 66])

# %%
a -b
# Out:
# array([ 11, -11,   0])

# %%
a * b
# Out:
# array([ 242,  242, 1089])

# %%
a / b
# Out:
# array([2. , 0.5, 1. ])

# %%
# Mathematical Fuctions

# %%
sample_array = np.array([1,4,9])

# %%
sample_array
# Out:
# array([1, 4, 9])

# %%
np.sqrt(sample_array)
# Out:
# array([1., 2., 3.])

# %%
sample_array1 = np.array([22,25,125])

# %%
sample_array1
# Out:
# array([ 22,  25, 125])

# %%
np.sqrt(sample_array1)
# Out:
# array([ 4.69041576,  5.        , 11.18033989])

# %%
np.exp(sample_array)
# Out:
# array([2.71828183e+00, 5.45981500e+01, 8.10308393e+03])

# %%
np.exp(sample_array1)
# Out:
# array([3.58491285e+09, 7.20048993e+10, 1.93557604e+54])

# %%
np.log(sample_array)
# Out:
# array([0.        , 1.38629436, 2.19722458])

# %%
# Satistical Functions

# %%
sample_array = np.array([1,2,3,4,5])

# %%
sample_array
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.mean(sample_array)
# Out:
# np.float64(3.0)

# %%
np.median(sample_array)
# Out:
# np.float64(3.0)

# %%
np.std(sample_array)
# Out:
# np.float64(1.4142135623730951)

# %%
np.min(sample_array)
# Out:
# np.int64(1)

# %%
np.max(sample_array)
# Out:
# np.int64(5)

# %%
# Reshaping Arrays

# %%
sample_array = np.arange(6)

# %%
sample_array
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
reshape = sample_array.reshape(2,3)

# %%
reshape
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
# flatterning

# %%
sample_array = np.array([[1,2],[3,4]])

# %%
sample_array
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
sample_array.flatten()
# Out:
# array([1, 2, 3, 4])

# %%
sample_tensor_3 = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])

# %%
sample_tensor_3.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
# joining Arrays

# %%
a = np.array([1,2,])

# %%
b = np.array([3,4])

# %%
a
# Out:
# array([22, 11, 33])

# %%
b
# Out:
# array([3, 4])

# %%
np.concatenate((a,b))
# Out:
# array([22, 11, 33,  3,  4])

# %%
#splitting Arrays

# %%
sample_array = np.array([1,2,3,4])

# %%
sample_array
# Out:
# array([1, 2, 3, 4])

# %%
np.array_split(sample_array,2)
# Out:
# [array([1, 2]), array([3, 4])]

# %%
# Random module

# %%
np.random.rand(3)
# Out:
# array([0.33668809, 0.57513444, 0.3544408 ])

# %%
np.random.randint(1,10,5)
# Out:
# array([6, 5, 9, 6, 6], dtype=int32)

# %%
sample_array = np.array([[1,2],[3,4]])

# %%
sample_array
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.sum(sample_array, axis=0)
# Out:
# array([4, 6])

# %%
np.sum(sample_array, axis=1)
# Out:
# array([3, 7])

# %%
# NaN & Missing Values

# %%
sample_array=np.array([1,np.nan,3])

# %%
sample_array
# Out:
# array([ 1., nan,  3.])

# %%
np.isnan(sample_array)
# Out:
# array([False,  True, False])

# %%
# create 2 numpy array and per form element wise addition sub,mul,diviion,modulas operation

# %%
a = np.array([1,2,3,4])
b = np.array([5,6,7,8,])

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
b
# Out:
# array([5, 6, 7, 8])

# %%
a+b
# Out:
# array([ 6,  8, 10, 12])

# %%
a % b
# Out:
# array([1, 2, 3, 4])

# %%
a*b
# Out:
# array([ 5, 12, 21, 32])
