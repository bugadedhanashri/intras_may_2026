# %%
# docstring

# %%
sent = """
thiss is a multi-line string.
it can span multiple lines.
it is often used for docstrings.

"""

# %%
print(sent)
# Out:
# thiss is a multi-line string.
# it can span multiple lines.
# it is often used for docstrings.

# %%
sent = "Hello python"

# %%
sent[0]
# Out:
# 'H'

# %%
sent[0:5]
# Out:
# 'Hello'

# %%
# take a string as user input
# print the output => index and character

# %%
c = 0
sent = input("Enter the string:")
for i in sent:
    print(f"index:{c}, character: {i}")
    c += 1
# Out:
# Enter the string: rose are red
# index:0, character: r
# index:1, character: o
# index:2, character: s
# index:3, character: e
# index:4, character:
# index:5, character: a
# index:6, character: r
# index:7, character: e
# index:8, character:
# index:9, character: r
# index:10, character: e
# index:11, character: d

# %%
sent = "ajit kumar; age: 25; city: delhi; hobby: coding"

# %%
type(sent)
# Out:
# str

# %%
sent.split(";")
# Out:
# ['ajit kumar', ' age: 25', ' city: delhi', ' hobby: coding']

# %%
sent.find("kumar")
# Out:
# 5

# %%
sent.find("k")
# Out:
# 5

# %%
s1 = "hello"

# %%
s1.find("llo")
# Out:
# 2

# %%
s1.index("llo")
# Out:
# 2

# %%
#split -> it split the stri ng based on the given delimeter and return a list of substrings
#join ->opposite of split

# %%
l = ["hello","word","python"]

# %%
' '.join(l)
# Out:
# 'hello word python'

# %%
'=='.join(l)
# Out:
# 'hello==word==python'

# %%
#  user -> string
# using loop split into indiviuaal character and store in a list

# %%
sent = input("Enter a string:")

l = []

for i in sent:
    l.append(i)
    
    print(l)
# Out:
# Enter a string: SHIVRAJ
# ['S']
# ['S', 'H']
# ['S', 'H', 'I']
# ['S', 'H', 'I', 'V']
# ['S', 'H', 'I', 'V', 'R']
# ['S', 'H', 'I', 'V', 'R', 'A']
# ['S', 'H', 'I', 'V', 'R', 'A', 'J']

# %%
"""
use a loop if else to check if a specific character is present in the string or not get
output of both if the character is present and if it is not present
take 2 characters to check in the string
user input ->string, character1,character2
""";

# %%
text = input("Enter a string:")

char1 = input("Enter a first character to check:")
char2 = input("Enter a second character to check:")
found_char1 = false
found_char2 = false

for char in text:
    if char == char1:
        found_char1 = True
        found_char2 = True

if found_char1:
    print(f"the character '{char1}' is present in the string.")
else:
    print(f"the character '{char1}' is not present in the string.")
    if found_char2:
    print(f"the character '{char2}' is present in the string.")
# Out:
# Enter a string: amiz
# Enter a first character to check: a
# Enter a second character to check: z
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       3 char1 = input("Enter a first character to check:")
#       4 char2 = input("Enter a second character to check:")
# ----> 5 found_char1 = false
#       6 found_char2 = false
#       8 for char in text:
#
# NameError: name 'false' is not defined

# %%
# escape sequences

# %%
print("i like python programming\nits easy")
# Out:
# i like python programming
# its easy

# %%
print("i like python programming\t its easy")
# Out:
# i like python programming	 its easy

# %%
print("i like python programming\\its easy")
# Out:
# i like python programming\its easy

# %%
print("i like python programming its easy")
# Out:
# i like python programming its easy

# %%
print("i like python programming\" its easy")
# Out:
# i like python programming" its easy

# %%
name = "ajit"
marks = 85

# %%
"my name is {} and my marks are {}".format(name, marks)
# Out:
# 'my name is ajit and my marks are 85'
