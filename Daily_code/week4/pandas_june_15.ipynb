# %%
# Pandas

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#1D data structure in pandas

# %%
# pandas Series

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
d = pd.Series([11,22,33,44,55])

# %%
d
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
# with Custom Index

# %%
s = pd.Series([10,20,30], index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s = pd.Series(['Amit',20,300], index=['name','age','marks'])

# %%
s
# Out:
# name     Amit
# age        20
# marks     300
# dtype: object

# %%
# from Dictionary

# %%
data = {'name':"Amit",'Age':20,'Marks':92}

# %%
s = pd.Series(data)

# %%
s
# Out:
# name     Amit
# Age        20
# Marks      92
# dtype: object

# %%
data = {'id':101,'name':"Amit",'salary':'90,000'}

# %%
s = pd.Series(data)

# %%
s
# Out:
# id           101
# name        Amit
# salary    90,000
# dtype: object

# %%
# from a single value

# %%
s = pd.Series(5,index=[0,1,2,3,4,5])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
s = pd.Series(5, index=[0,1,2,3,4,5])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
#Attribute

# %%
s = pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
s.size
# Out:
# 3

# %%
# data manupulation

# %%
s = pd.Series([1,2,3])

# %%
print(s*3)
# Out:
# 0    3
# 1    6
# 2    9
# dtype: int64

# %%
# handaling missing values

# %%
s = pd.Series([1,None,3])

# %%
s
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    0.0
# 2    3.0
# dtype: float64

# %%
#Indexing

# %%
s = pd.Series([10,20,30,], index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['c']
# Out:
# np.int64(30)
