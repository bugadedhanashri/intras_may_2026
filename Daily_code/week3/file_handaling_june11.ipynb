# %%
"""
create a sample text file with some text in it
""";

# %%
# r open file regarding .(default)

# %%
# open the file

# %%
f = open("sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# "'A Wiki is a website that any one can particepate in.from wiriting about your fevorite topic , to adding a photo or fixing a typo,a wiki is a place where anyone can contribute and collab wikis are communicate of pepole who share a common interest, and love to write,chat and chronicle that interest.'\n"

# %%
f.readline()
# Out:
# '\n'

# %%
f.readline()
# Out:
# 'done\n'

# %%
f.readline()
# Out:
# 'done'

# %%
f = open("sample.txt")

# %%
f.readline(10)
# Out:
# "'A Wiki is"

# %%
f.readline(5)
# Out:
# ' a we'

# %%
f.tell()
# Out:
# 15

# %%
f.seek(10)
# Out:
# 10

# %%
f.readline(5)
# Out:
# ' a we'

# %%
# check the readlines()

# %%
f = open("sample.txt")

# %%
data = f.readlines()

# %%
data
# Out:
# ["'A Wiki is a website that any one can particepate in.from wiriting about your fevorite topic , to adding a photo or fixing a typo,a wiki is a place where anyone can contribute and collab wikis are communicate of pepole who share a common interest, and love to write,chat and chronicle that interest.'\n",
#  '\n',
#  'done\n',
#  'done']

# %%
for line in data:
    print(line)
# Out:
# 'A Wiki is a website that any one can particepate in.from wiriting about your fevorite topic , to adding a photo or fixing a typo,a wiki is a place where anyone can contribute and collab wikis are communicate of pepole who share a common interest, and love to write,chat and chronicle that interest.'
#
#
#
# done
#
# done

# %%
# conver data into a uppercase

# %%
for line in data:
    print(line.upper())
# Out:
# 'A WIKI IS A WEBSITE THAT ANY ONE CAN PARTICEPATE IN.FROM WIRITING ABOUT YOUR FEVORITE TOPIC , TO ADDING A PHOTO OR FIXING A TYPO,A WIKI IS A PLACE WHERE ANYONE CAN CONTRIBUTE AND COLLAB WIKIS ARE COMMUNICATE OF PEPOLE WHO SHARE A COMMON INTEREST, AND LOVE TO WRITE,CHAT AND CHRONICLE THAT INTEREST.'
#
#
#
# DONE
#
# DONE

# %%
# read fuction

# %%
f = open("sample.txt")

# %%
text = f.read()

# %%
text
# Out:
# "'A Wiki is a website that any one can particepate in.from wiriting about your fevorite topic , to adding a photo or fixing a typo,a wiki is a place where anyone can contribute and collab wikis are communicate of pepole who share a common interest, and love to write,chat and chronicle that interest.'\n\ndone\ndone"

# %%
print(text)
# Out:
# 'A Wiki is a website that any one can particepate in.from wiriting about your fevorite topic , to adding a photo or fixing a typo,a wiki is a place where anyone can contribute and collab wikis are communicate of pepole who share a common interest, and love to write,chat and chronicle that interest.'
#
# done
# done

# %%
text.split();

# %%
m = open('marathi.txt', encoding= 'utf-8')

# %%
print(m.read())
# Out:
# कुलवाडी-भूषण पवाडा गाळो भोसल्याचा ।छत्रपती शिवाजीचा ॥ धृ० ॥पंधराशें एकूणपन्नास साल फळलें ।जन्नम जुन्नरमध्यें उदयासी आलें ॥शिवनेरी किल्ल्यामध्यें बाळ शिवाजी जन्मलें ।जिजाबाईस रत्न सांपडलें ॥सान कटी सिंहापरी छाती मांस दुणावलें ।नांव शिवाजी शोभलें ॥राजहौंसी उंच मान माघें सांदिली ।एकसारखे शुभ्र दांत चमंकू लागले ।मोतीड्यांची माळ गुंफिली

# %%
m.close
# Out:
# <function TextIOWrapper.close()>

# %%
m.readable()
# Out:
# True

# %%
# opening a file with context manager

# %%
with open('sample.txt') as f:
    data = f.read()

# %%
print(data)
# Out:
# 'A Wiki is a website that any one can particepate in.from wiriting about your fevorite topic , to adding a photo or fixing a typo,a wiki is a place where anyone can contribute and collab wikis are communicate of pepole who share a common interest, and love to write,chat and chronicle that interest.'
#
# done
# done

# %%
# writing in a file

# %%
f = open('myfile.txt', 'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines = ['frodo took the ring','he started his journy to mount doom']

# %%
f.writelines(lines)

# %%
f.close()

# %%
# writelines -> takes the list of sentance from user and write them in the file

# %%
#write()

# %%
sent = "frodo took the ring. he started his journy te mount dom."

# %%
f = open('myfile.txt', 'w')
f.write(sent)
f.close()

# %%
#write into myfile.txt with context manager
#use write fuction and add 3 separate

# %%
with open('myfile.txt', 'w') as f:
    f.write('this is first line\n')
    f.write('this is second\n')
    f.write('this is third\n')

# %%
# simple file copy operation

# %%
s = open('sample.txt', 'r')
f = open('myfile.txt', 'w')

# %%
contents = s.read()
f.write(contents)
f.close()

# %%
# append

# %%
s = open('sample.txt', 'a')

# %%
s.write('\ndone')
# Out:
# 5

# %%
s.close()
